# %% [markdown]
# <a href="https://colab.research.google.com/github/yamrajkhadka/Land-Cover-Classification-from-Satellite-Images-using-U-Net-on-the-DeepGlobe-Dataset/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install kaggle
# Set up Kaggle API credentials
import os
os.environ['KAGGLE_USERNAME'] = 'yamrajkhadka01'
os.environ['KAGGLE_KEY'] = '/content/kaggle (5).json'
# Download the dataset
# !kaggle datasets download -d balraj98/deepglobe-land-cover-classification-dataset -p /content/
# Unzip the dataset
# !unzip -q /content/deepglobe-land-cover-classification-dataset.zip -d /content/deepglobe_dataset/
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Dataset URL: https://www.kaggle.com/datasets/balraj98/deepglobe-land-cover-classification-dataset
# License(s): other
# Downloading deepglobe-land-cover-classification-dataset.zip to /content
#  98% 2.67G/2.74G [00:24<00:01, 56.3MB/s]
# 100% 2.74G/2.74G [00:24<00:00, 121MB/s]

# %%
# Full Colab-ready Code for DeepGlobe Segmentation using U-Net with Improvements

import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback
import albumentations as A

# 1. Load Class Mapping
CLASS_DICT_CSV = '/content/deepglobe_dataset/class_dict.csv'
assert os.path.exists(CLASS_DICT_CSV), "class_dict.csv not found!"

class_dict = pd.read_csv(CLASS_DICT_CSV)
color2class = {(row['r'], row['g'], row['b']): idx for idx, row in class_dict.iterrows()}
NUM_CLASSES = len(class_dict)

def rgb_to_class(mask_rgb):
    h, w, _ = mask_rgb.shape
    mask_class = np.zeros((h, w), dtype=np.uint8)
    for color, class_idx in color2class.items():
        matches = np.all(mask_rgb == color, axis=-1)
        mask_class[matches] = class_idx
    return mask_class

def class_to_rgb(mask_class):
    h, w = mask_class.shape
    mask_rgb = np.zeros((h, w, 3), dtype=np.uint8)
    for color, class_idx in color2class.items():
        mask_rgb[mask_class == class_idx] = color
    return mask_rgb

# 2. Load Dataset and Apply Augmentations
TRAIN_IMG_DIR = '/content/deepglobe_dataset/train'
assert os.path.exists(TRAIN_IMG_DIR), "Train directory not found!"

IMG_SIZE = (256, 256)
img_ids = [f[:-8] for f in os.listdir(TRAIN_IMG_DIR) if f.endswith('_sat.jpg')]
N = min(1000, len(img_ids))

transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomBrightnessContrast(p=0.3),
    A.Affine(rotate=(-15, 15), scale=(0.9, 1.1), translate_percent=0.1, p=0.5),
])

X, Y = [], []
for img_id in img_ids[:N]:
    img_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_sat.jpg")
    mask_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_mask.png")

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)

    augmented = transform(image=img, mask=mask)
    img = cv2.resize(augmented['image'], IMG_SIZE)
    mask = cv2.resize(augmented['mask'], IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    img = img / 255.0
    mask_class = rgb_to_class(mask)
    mask_onehot = to_categorical(mask_class, num_classes=NUM_CLASSES)

    X.append(img)
    Y.append(mask_onehot)

X = np.array(X, dtype=np.float32)
Y = np.array(Y, dtype=np.float32)
print(f"X: {X.shape} Y: {Y.shape}")

# 3. Compute Class Weights
flat_mask = np.argmax(Y, axis=-1).reshape(-1)
class_counts = np.bincount(flat_mask, minlength=NUM_CLASSES)
class_weights = class_counts.max() / (class_counts + 1e-6)
class_weights = class_weights / class_weights.sum() * NUM_CLASSES
print("Class weights:", class_weights)

# 4. Custom Focal Loss
from tensorflow.keras import backend as K
def categorical_focal_loss(alpha, gamma=2.0):
    alpha = tf.constant(alpha, dtype=tf.float32)
    def loss_fn(y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        y_pred = tf.clip_by_value(y_pred, K.epsilon(), 1. - K.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma)
        focal_loss = weight * cross_entropy
        return tf.reduce_mean(tf.reduce_sum(focal_loss, axis=-1))
    return loss_fn

loss_fn = categorical_focal_loss(class_weights)

# 5. Mean IoU Metric
class MeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, name='mean_iou', **kwargs):
        super().__init__(num_classes=num_classes, name=name, **kwargs)
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.argmax(y_true, axis=-1)
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# 6. Build U-Net Model

def build_unet(input_shape=(256, 256, 3), num_classes=NUM_CLASSES):
    def conv_block(x, filters):
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        return x

    inputs = Input(input_shape)
    c1 = conv_block(inputs, 32); p1 = MaxPooling2D()(c1)
    c2 = conv_block(p1, 64); p2 = MaxPooling2D()(c2)
    c3 = conv_block(p2, 128); p3 = MaxPooling2D()(c3)
    c4 = conv_block(p3, 256); p4 = MaxPooling2D()(c4)
    b = conv_block(p4, 512); b = Dropout(0.4)(b)
    u1 = Conv2DTranspose(256, 2, strides=2, padding='same')(b); u1 = concatenate([u1, c4]); c5 = conv_block(u1, 256)
    u2 = Conv2DTranspose(128, 2, strides=2, padding='same')(c5); u2 = concatenate([u2, c3]); c6 = conv_block(u2, 128)
    u3 = Conv2DTranspose(64, 2, strides=2, padding='same')(c6); u3 = concatenate([u3, c2]); c7 = conv_block(u3, 64)
    u4 = Conv2DTranspose(32, 2, strides=2, padding='same')(c7); u4 = concatenate([u4, c1]); c8 = conv_block(u4, 32)
    outputs = Conv2D(num_classes, 1, activation='softmax')(c8)
    return Model(inputs, outputs)

model = build_unet()
model.compile(optimizer='adam', loss=loss_fn, metrics=[MeanIoU(NUM_CLASSES)])
model.summary()

# 7. Training with Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-5, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

history = model.fit(
    X, Y,
    validation_split=0.2,
    epochs=200,
    batch_size=8,
    shuffle=True,
    callbacks=[reduce_lr, early_stop],
    verbose=1
)

# 8. Plot Per-Class IoU
preds = model.predict(X)
preds_class = np.argmax(preds, axis=-1)
true_class = np.argmax(Y, axis=-1)

ious = []
for i in range(NUM_CLASSES):
    intersection = np.logical_and(preds_class == i, true_class == i).sum()
    union = np.logical_or(preds_class == i, true_class == i).sum()
    iou = intersection / (union + 1e-6)
    ious.append(iou)
    print(f"Class {i} IoU: {iou:.4f}")

print("Mean IoU:", np.mean(ious))
# Out:
# X: (803, 256, 256, 3) Y: (803, 256, 256, 7)
# Class weights: [0.76662306 0.14388482 0.97833991 0.75141309 2.50358822 0.99213277
#  0.86401812]
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ dropout[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │        231 │ batch_normalizat… │
# │                     │ 7)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,772,071 (29.65 MB)
#  Trainable params: 7,766,183 (29.63 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 85s 546ms/step - loss: 0.6633 - mean_iou: 0.2250 - val_loss: 1.1755 - val_mean_iou: 0.0250 - learning_rate: 0.0010
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 24s 180ms/step - loss: 0.4328 - mean_iou: 0.3253 - val_loss: 1.0129 - val_mean_iou: 0.0378 - learning_rate: 0.0010
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 177ms/step - loss: 0.3956 - mean_iou: 0.3428 - val_loss: 1.2142 - val_mean_iou: 0.0109 - learning_rate: 0.0010
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 178ms/step - loss: 0.3970 - mean_iou: 0.3400 - val_loss: 0.8209 - val_mean_iou: 0.0322 - learning_rate: 0.0010
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 179ms/step - loss: 0.3431 - mean_iou: 0.3704 - val_loss: 1.0878 - val_mean_iou: 0.0420 - learning_rate: 0.0010
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 179ms/step - loss: 0.3628 - mean_iou: 0.3530 - val_loss: 0.8466 - val_mean_iou: 0.0988 - learning_rate: 0.0010
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.3541 - mean_iou: 0.3555 - val_loss: 0.6919 - val_mean_iou: 0.2226 - learning_rate: 0.0010
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.3529 - mean_iou: 0.3598 - val_loss: 0.3126 - val_mean_iou: 0.3632 - learning_rate: 0.0010
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 180ms/step - loss: 0.3613 - mean_iou: 0.3724 - val_loss: 0.4084 - val_mean_iou: 0.3115 - learning_rate: 0.0010
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - loss: 0.3314 - mean_iou: 0.3751 - val_loss: 0.3149 - val_mean_iou: 0.3598 - learning_rate: 0.0010
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - loss: 0.3110 - mean_iou: 0.3874 - val_loss: 0.5363 - val_mean_iou: 0.2834 - learning_rate: 0.0010
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.3237 - mean_iou: 0.3996 - val_loss: 0.6791 - val_mean_iou: 0.1458 - learning_rate: 0.0010
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 182ms/step - loss: 0.3320 - mean_iou: 0.3812 - val_loss: 0.3442 - val_mean_iou: 0.3629 - learning_rate: 0.0010
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - loss: 0.3073 - mean_iou: 0.4064 - val_loss: 0.8392 - val_mean_iou: 0.2011 - learning_rate: 0.0010
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 181ms/step - loss: 0.3020 - mean_iou: 0.4084 - val_loss: 0.3285 - val_mean_iou: 0.4139 - learning_rate: 0.0010
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 184ms/step - loss: 0.2960 - mean_iou: 0.4180 - val_loss: 0.2802 - val_mean_iou: 0.4070 - learning_rate: 0.0010
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.3002 - mean_iou: 0.4078 - val_loss: 0.3080 - val_mean_iou: 0.3725 - learning_rate: 0.0010
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - loss: 0.3047 - mean_iou: 0.3982 - val_loss: 0.3731 - val_mean_iou: 0.3633 - learning_rate: 0.0010
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.3022 - mean_iou: 0.4079 - val_loss: 0.2929 - val_mean_iou: 0.3523 - learning_rate: 0.0010
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - loss: 0.2882 - mean_iou: 0.4124 - val_loss: 0.4499 - val_mean_iou: 0.3049 - learning_rate: 0.0010
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 181ms/step - loss: 0.2930 - mean_iou: 0.3816 - val_loss: 0.4873 - val_mean_iou: 0.2993 - learning_rate: 0.0010
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 182ms/step - loss: 0.2848 - mean_iou: 0.4362 - val_loss: 0.2554 - val_mean_iou: 0.4094 - learning_rate: 0.0010
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.2819 - mean_iou: 0.4347 - val_loss: 0.2978 - val_mean_iou: 0.4211 - learning_rate: 0.0010
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - loss: 0.2597 - mean_iou: 0.4390 - val_loss: 0.3582 - val_mean_iou: 0.3186 - learning_rate: 0.0010
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.2961 - mean_iou: 0.4279 - val_loss: 0.2295 - val_mean_iou: 0.4820 - learning_rate: 0.0010
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.2594 - mean_iou: 0.4475 - val_loss: 0.3520 - val_mean_iou: 0.3430 - learning_rate: 0.0010
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.2519 - mean_iou: 0.4386 - val_loss: 0.2614 - val_mean_iou: 0.4213 - learning_rate: 0.0010
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.2522 - mean_iou: 0.4394 - val_loss: 0.2570 - val_mean_iou: 0.3728 - learning_rate: 0.0010
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - loss: 0.2677 - mean_iou: 0.4263 - val_loss: 0.2193 - val_mean_iou: 0.4742 - learning_rate: 0.0010
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.2523 - mean_iou: 0.4496 - val_loss: 0.2990 - val_mean_iou: 0.4051 - learning_rate: 0.0010
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.2631 - mean_iou: 0.4247 - val_loss: 0.3901 - val_mean_iou: 0.2934 - learning_rate: 0.0010
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.2576 - mean_iou: 0.4407 - val_loss: 0.3894 - val_mean_iou: 0.3043 - learning_rate: 0.0010
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.2402 - mean_iou: 0.4488 - val_loss: 0.2982 - val_mean_iou: 0.3993 - learning_rate: 0.0010
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.2469 - mean_iou: 0.4401 - val_loss: 0.3890 - val_mean_iou: 0.3059 - learning_rate: 0.0010
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 182ms/step - loss: 0.2680 - mean_iou: 0.4439 - val_loss: 0.3245 - val_mean_iou: 0.3721 - learning_rate: 0.0010
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - loss: 0.2545 - mean_iou: 0.4425 - val_loss: 0.4537 - val_mean_iou: 0.2942 - learning_rate: 0.0010
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.2575 - mean_iou: 0.4386
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.2575 - mean_iou: 0.4387 - val_loss: 0.3105 - val_mean_iou: 0.4094 - learning_rate: 0.0010
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 184ms/step - loss: 0.2278 - mean_iou: 0.4865 - val_loss: 0.2437 - val_mean_iou: 0.4139 - learning_rate: 5.0000e-04
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.2211 - mean_iou: 0.5203 - val_loss: 0.2181 - val_mean_iou: 0.5038 - learning_rate: 5.0000e-04
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - loss: 0.2093 - mean_iou: 0.5048 - val_loss: 0.2347 - val_mean_iou: 0.4820 - learning_rate: 5.0000e-04
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.2239 - mean_iou: 0.4915 - val_loss: 0.2011 - val_mean_iou: 0.5089 - learning_rate: 5.0000e-04
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.2156 - mean_iou: 0.4976 - val_loss: 0.2099 - val_mean_iou: 0.4899 - learning_rate: 5.0000e-04
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.2083 - mean_iou: 0.4812 - val_loss: 0.2875 - val_mean_iou: 0.4851 - learning_rate: 5.0000e-04
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.2192 - mean_iou: 0.4747 - val_loss: 0.2402 - val_mean_iou: 0.4617 - learning_rate: 5.0000e-04
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - loss: 0.2104 - mean_iou: 0.5054 - val_loss: 0.2017 - val_mean_iou: 0.5058 - learning_rate: 5.0000e-04
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.2070 - mean_iou: 0.4822 - val_loss: 0.2036 - val_mean_iou: 0.4863 - learning_rate: 5.0000e-04
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.2048 - mean_iou: 0.5068 - val_loss: 0.2099 - val_mean_iou: 0.4479 - learning_rate: 5.0000e-04
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - loss: 0.2002 - mean_iou: 0.5212 - val_loss: 0.2015 - val_mean_iou: 0.4993 - learning_rate: 5.0000e-04
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.2172 - mean_iou: 0.5169
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.2171 - mean_iou: 0.5167 - val_loss: 0.2937 - val_mean_iou: 0.4046 - learning_rate: 5.0000e-04
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.1955 - mean_iou: 0.5054 - val_loss: 0.1857 - val_mean_iou: 0.5210 - learning_rate: 2.5000e-04
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 184ms/step - loss: 0.1941 - mean_iou: 0.5381 - val_loss: 0.1809 - val_mean_iou: 0.5008 - learning_rate: 2.5000e-04
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.1856 - mean_iou: 0.5445 - val_loss: 0.1768 - val_mean_iou: 0.5415 - learning_rate: 2.5000e-04
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - loss: 0.1825 - mean_iou: 0.5243 - val_loss: 0.1741 - val_mean_iou: 0.5158 - learning_rate: 2.5000e-04
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1826 - mean_iou: 0.5306 - val_loss: 0.1875 - val_mean_iou: 0.5256 - learning_rate: 2.5000e-04
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.1844 - mean_iou: 0.5286 - val_loss: 0.2115 - val_mean_iou: 0.4681 - learning_rate: 2.5000e-04
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 184ms/step - loss: 0.1837 - mean_iou: 0.5299 - val_loss: 0.2008 - val_mean_iou: 0.5022 - learning_rate: 2.5000e-04
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1750 - mean_iou: 0.5439 - val_loss: 0.1816 - val_mean_iou: 0.5212 - learning_rate: 2.5000e-04
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.1780 - mean_iou: 0.5250 - val_loss: 0.1815 - val_mean_iou: 0.4826 - learning_rate: 2.5000e-04
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1762 - mean_iou: 0.5584 - val_loss: 0.1833 - val_mean_iou: 0.4997 - learning_rate: 2.5000e-04
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - loss: 0.1765 - mean_iou: 0.5579 - val_loss: 0.1837 - val_mean_iou: 0.5074 - learning_rate: 2.5000e-04
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - loss: 0.1735 - mean_iou: 0.5510
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.1735 - mean_iou: 0.5509 - val_loss: 0.2025 - val_mean_iou: 0.5046 - learning_rate: 2.5000e-04
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1792 - mean_iou: 0.5518 - val_loss: 0.1664 - val_mean_iou: 0.5401 - learning_rate: 1.2500e-04
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.1705 - mean_iou: 0.5550 - val_loss: 0.1728 - val_mean_iou: 0.5279 - learning_rate: 1.2500e-04
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.1583 - mean_iou: 0.5580 - val_loss: 0.1665 - val_mean_iou: 0.5486 - learning_rate: 1.2500e-04
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1585 - mean_iou: 0.5495 - val_loss: 0.1694 - val_mean_iou: 0.5395 - learning_rate: 1.2500e-04
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - loss: 0.1725 - mean_iou: 0.5560 - val_loss: 0.1654 - val_mean_iou: 0.5485 - learning_rate: 1.2500e-04
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.1622 - mean_iou: 0.5471 - val_loss: 0.1758 - val_mean_iou: 0.5207 - learning_rate: 1.2500e-04
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1623 - mean_iou: 0.5529 - val_loss: 0.1635 - val_mean_iou: 0.5488 - learning_rate: 1.2500e-04
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1620 - mean_iou: 0.5786 - val_loss: 0.1759 - val_mean_iou: 0.5277 - learning_rate: 1.2500e-04
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - loss: 0.1664 - mean_iou: 0.5649 - val_loss: 0.1738 - val_mean_iou: 0.5332 - learning_rate: 1.2500e-04
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 187ms/step - loss: 0.1682 - mean_iou: 0.5596 - val_loss: 0.1602 - val_mean_iou: 0.5428 - learning_rate: 1.2500e-04
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1555 - mean_iou: 0.5725 - val_loss: 0.1678 - val_mean_iou: 0.5344 - learning_rate: 1.2500e-04
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1632 - mean_iou: 0.5594 - val_loss: 0.1756 - val_mean_iou: 0.5244 - learning_rate: 1.2500e-04
# Epoch 74/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1519 - mean_iou: 0.5618 - val_loss: 0.1594 - val_mean_iou: 0.5540 - learning_rate: 1.2500e-04
# Epoch 75/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.1678 - mean_iou: 0.5718 - val_loss: 0.1673 - val_mean_iou: 0.5253 - learning_rate: 1.2500e-04
# Epoch 76/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.1488 - mean_iou: 0.5741 - val_loss: 0.1625 - val_mean_iou: 0.5492 - learning_rate: 1.2500e-04
# Epoch 77/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1656 - mean_iou: 0.5723 - val_loss: 0.1710 - val_mean_iou: 0.5325 - learning_rate: 1.2500e-04
# Epoch 78/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.1542 - mean_iou: 0.5511 - val_loss: 0.1632 - val_mean_iou: 0.5373 - learning_rate: 1.2500e-04
# Epoch 79/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1498 - mean_iou: 0.5865 - val_loss: 0.1717 - val_mean_iou: 0.5314 - learning_rate: 1.2500e-04
# Epoch 80/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1548 - mean_iou: 0.5628 - val_loss: 0.1667 - val_mean_iou: 0.5150 - learning_rate: 1.2500e-04
# Epoch 81/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1528 - mean_iou: 0.5704 - val_loss: 0.1634 - val_mean_iou: 0.5575 - learning_rate: 1.2500e-04
# Epoch 82/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.1526 - mean_iou: 0.5666
# Epoch 82: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 184ms/step - loss: 0.1527 - mean_iou: 0.5666 - val_loss: 0.1666 - val_mean_iou: 0.5315 - learning_rate: 1.2500e-04
# Epoch 83/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.1530 - mean_iou: 0.5752 - val_loss: 0.1616 - val_mean_iou: 0.5402 - learning_rate: 6.2500e-05
# Epoch 84/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.1409 - mean_iou: 0.5713 - val_loss: 0.1618 - val_mean_iou: 0.5425 - learning_rate: 6.2500e-05
# Epoch 85/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.1599 - mean_iou: 0.5383 - val_loss: 0.1608 - val_mean_iou: 0.5411 - learning_rate: 6.2500e-05
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.1502 - mean_iou: 0.5806 - val_loss: 0.1640 - val_mean_iou: 0.5479 - learning_rate: 6.2500e-05
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1438 - mean_iou: 0.5857 - val_loss: 0.1667 - val_mean_iou: 0.5334 - learning_rate: 6.2500e-05
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 183ms/step - loss: 0.1498 - mean_iou: 0.5717 - val_loss: 0.1591 - val_mean_iou: 0.5448 - learning_rate: 6.2500e-05
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1500 - mean_iou: 0.5826 - val_loss: 0.1630 - val_mean_iou: 0.5399 - learning_rate: 6.2500e-05
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 182ms/step - loss: 0.1405 - mean_iou: 0.5603 - val_loss: 0.1602 - val_mean_iou: 0.5505 - learning_rate: 6.2500e-05
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1508 - mean_iou: 0.5860 - val_loss: 0.1586 - val_mean_iou: 0.5520 - learning_rate: 6.2500e-05
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1496 - mean_iou: 0.5788 - val_loss: 0.1588 - val_mean_iou: 0.5478 - learning_rate: 6.2500e-05
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 186ms/step - loss: 0.1454 - mean_iou: 0.5679 - val_loss: 0.1605 - val_mean_iou: 0.5538 - learning_rate: 6.2500e-05
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1548 - mean_iou: 0.5999 - val_loss: 0.1601 - val_mean_iou: 0.5586 - learning_rate: 6.2500e-05
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1439 - mean_iou: 0.5844 - val_loss: 0.1577 - val_mean_iou: 0.5554 - learning_rate: 6.2500e-05
# Epoch 96/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1471 - mean_iou: 0.5803 - val_loss: 0.1608 - val_mean_iou: 0.5401 - learning_rate: 6.2500e-05
# Epoch 97/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.1470 - mean_iou: 0.5751 - val_loss: 0.1686 - val_mean_iou: 0.5289 - learning_rate: 6.2500e-05
# Epoch 98/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1417 - mean_iou: 0.5814 - val_loss: 0.1640 - val_mean_iou: 0.5451 - learning_rate: 6.2500e-05
# Epoch 99/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1458 - mean_iou: 0.6114 - val_loss: 0.1630 - val_mean_iou: 0.5424 - learning_rate: 6.2500e-05
# Epoch 100/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.1429 - mean_iou: 0.5802 - val_loss: 0.1594 - val_mean_iou: 0.5627 - learning_rate: 6.2500e-05
# Epoch 101/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - loss: 0.1353 - mean_iou: 0.5963 - val_loss: 0.1644 - val_mean_iou: 0.5392 - learning_rate: 6.2500e-05
# Epoch 102/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 185ms/step - loss: 0.1407 - mean_iou: 0.5924 - val_loss: 0.1611 - val_mean_iou: 0.5404 - learning_rate: 6.2500e-05
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.1434 - mean_iou: 0.5800
# Epoch 103: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1434 - mean_iou: 0.5801 - val_loss: 0.1631 - val_mean_iou: 0.5435 - learning_rate: 6.2500e-05
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 185ms/step - loss: 0.1309 - mean_iou: 0.5982 - val_loss: 0.1586 - val_mean_iou: 0.5594 - learning_rate: 3.1250e-05
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - loss: 0.1390 - mean_iou: 0.5784 - val_loss: 0.1625 - val_mean_iou: 0.5469 - learning_rate: 3.1250e-05
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.1431 - mean_iou: 0.5888 - val_loss: 0.1609 - val_mean_iou: 0.5521 - learning_rate: 3.1250e-05
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 186ms/step - loss: 0.1409 - mean_iou: 0.5888 - val_loss: 0.1613 - val_mean_iou: 0.5502 - learning_rate: 3.1250e-05
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1428 - mean_iou: 0.5810 - val_loss: 0.1588 - val_mean_iou: 0.5489 - learning_rate: 3.1250e-05
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 184ms/step - loss: 0.1455 - mean_iou: 0.5931 - val_loss: 0.1589 - val_mean_iou: 0.5524 - learning_rate: 3.1250e-05
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - loss: 0.1360 - mean_iou: 0.5889 - val_loss: 0.1596 - val_mean_iou: 0.5521 - learning_rate: 3.1250e-05
# Epoch 110: early stopping
# Restoring model weights from the end of the best epoch: 95.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 26s 423ms/step
# Class 0 IoU: 0.6944
# Class 1 IoU: 0.6082
# Class 2 IoU: 0.2099
# Class 3 IoU: 0.7341
# Class 4 IoU: 0.5133
# Class 5 IoU: 0.5103
# Class 6 IoU: 0.9896
# Mean IoU: 0.60853261273811

# %%
# 7. Visualize predictions helper
def show_pred(i):
    img = X[i]
    true_mask = class_to_rgb(np.argmax(Y[i], axis=-1))
    pred = model.predict(np.expand_dims(img, 0), verbose=0)[0]
    pred_mask = class_to_rgb(np.argmax(pred, axis=-1))

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title('Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask)
    plt.title('True Mask')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask)
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.show()

print("Showing predictions for 3 random images:")
for i in np.random.choice(len(X), 3, replace=False):
    show_pred(i)
# Out:
# Showing predictions for 3 random images:

# %%
# 8. Save the model
model.save('deepglobe_unet_miou_improved_ioufix2.keras')

# For Colab: download saved model (optional)
try:
    from google.colab import files
    files.download('deepglobe_unet_miou_improved_ioufix2.keras')
except:
    print("File download skipped (not running in Colab).")
