# %% [markdown]
# <a href="https://colab.research.google.com/github/yamrajkhadka/Land-Cover-Classification-from-Satellite-Images-using-U-Net-on-the-DeepGlobe-Dataset/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install kaggle
# Set up Kaggle API credentials
import os
os.environ['KAGGLE_USERNAME'] = 'yamrajkhadka01'
os.environ['KAGGLE_KEY'] = '/content/kaggle (5).json'
# Download the dataset
# !kaggle datasets download -d balraj98/deepglobe-land-cover-classification-dataset -p /content/
# Unzip the dataset
# !unzip -q /content/deepglobe-land-cover-classification-dataset.zip -d /content/deepglobe_dataset/
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Dataset URL: https://www.kaggle.com/datasets/balraj98/deepglobe-land-cover-classification-dataset
# License(s): other
# Downloading deepglobe-land-cover-classification-dataset.zip to /content
#  99% 2.72G/2.74G [00:26<00:00, 109MB/s]
# 100% 2.74G/2.74G [00:26<00:00, 110MB/s]

# %%
# Improved U-Net for DeepGlobe with proper mIoU metric

# 1. Imports
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# 2. Load class color mapping (replace path with your DeepGlobe class dict CSV path)
CLASS_DICT_CSV = '/content/deepglobe_dataset/class_dict.csv'
assert os.path.exists(CLASS_DICT_CSV), "class_dict.csv not found!"

class_dict = pd.read_csv(CLASS_DICT_CSV)
color2class = {(row['r'], row['g'], row['b']): idx for idx, row in class_dict.iterrows()}
NUM_CLASSES = len(class_dict)

def rgb_to_class(mask_rgb):
    h, w, _ = mask_rgb.shape
    mask_class = np.zeros((h, w), dtype=np.uint8)
    for color, class_idx in color2class.items():
        matches = np.all(mask_rgb == color, axis=-1)
        mask_class[matches] = class_idx
    return mask_class

def class_to_rgb(mask_class):
    h, w = mask_class.shape
    mask_rgb = np.zeros((h, w, 3), dtype=np.uint8)
    for color, class_idx in color2class.items():
        mask_rgb[mask_class == class_idx] = color
    return mask_rgb

# 3. Load and preprocess dataset with stronger augmentation
TRAIN_IMG_DIR = '/content/deepglobe_dataset/train'
assert os.path.exists(TRAIN_IMG_DIR), "Train directory not found!"

IMG_SIZE = (128, 128)
img_ids = [f[:-8] for f in os.listdir(TRAIN_IMG_DIR) if f.endswith('_sat.jpg')]
N = min(1000, len(img_ids))  # Limit dataset size for faster training

X, Y = [], []
for img_id in img_ids[:N]:
    # Load image
    img_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_sat.jpg")
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE)
    img = img / 255.0  # Normalize to [0,1]

    # Load mask
    mask_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_mask.png")
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask_class = rgb_to_class(mask)
    mask_onehot = to_categorical(mask_class, num_classes=NUM_CLASSES)

    # Stronger augmentation (random flips and brightness jitter)
    if np.random.rand() < 0.5:
        img = np.fliplr(img)
        mask_onehot = np.fliplr(mask_onehot)
    if np.random.rand() < 0.3:
        img = np.flipud(img)
        mask_onehot = np.flipud(mask_onehot)
    if np.random.rand() < 0.3:
        img = img * (0.8 + 0.4 * np.random.rand())
        img = np.clip(img, 0, 1)

    X.append(img)
    Y.append(mask_onehot)

X = np.array(X, dtype=np.float32)
Y = np.array(Y, dtype=np.float32)
print(f"Loaded {len(X)} samples")
print("X shape:", X.shape, "Y shape:", Y.shape)

# 4. Custom MeanIoU Metric with argmax conversion
class MeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, name='mean_iou', **kwargs):
        super().__init__(num_classes=num_classes, name=name, **kwargs)

    def update_state(self, y_true, y_pred, sample_weight=None):
        # y_true is one-hot, convert to class indices
        y_true = tf.argmax(y_true, axis=-1)
        # y_pred is softmax probs, convert to predicted class indices
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# 5. U-Net model with minor improvements
def build_unet(input_shape=(128, 128, 3), num_classes=NUM_CLASSES):
    def conv_block(x, filters):
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        return x

    inputs = Input(input_shape)

    c1 = conv_block(inputs, 32)
    p1 = MaxPooling2D()(c1)

    c2 = conv_block(p1, 64)
    p2 = MaxPooling2D()(c2)

    c3 = conv_block(p2, 128)
    p3 = MaxPooling2D()(c3)

    c4 = conv_block(p3, 256)
    p4 = MaxPooling2D()(c4)

    b = conv_block(p4, 512)
    b = Dropout(0.4)(b)

    u1 = Conv2DTranspose(256, 2, strides=2, padding='same')(b)
    u1 = concatenate([u1, c4])
    c5 = conv_block(u1, 256)

    u2 = Conv2DTranspose(128, 2, strides=2, padding='same')(c5)
    u2 = concatenate([u2, c3])
    c6 = conv_block(u2, 128)

    u3 = Conv2DTranspose(64, 2, strides=2, padding='same')(c6)
    u3 = concatenate([u3, c2])
    c7 = conv_block(u3, 64)

    u4 = Conv2DTranspose(32, 2, strides=2, padding='same')(c7)
    u4 = concatenate([u4, c1])
    c8 = conv_block(u4, 32)

    outputs = Conv2D(num_classes, 1, activation='softmax')(c8)
    return Model(inputs, outputs)

model = build_unet()
model.compile(
    optimizer=Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy', MeanIoU(num_classes=NUM_CLASSES)]
)

model.summary()
# Out:
# Loaded 803 samples
# X shape: (803, 128, 128, 3) Y shape: (803, 128, 128, 7)
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_114 (Conv2D) │ (None, 128, 128,  │        896 │ input_layer_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_114[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_115 (Conv2D) │ (None, 128, 128,  │      9,248 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_115[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_24    │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_116 (Conv2D) │ (None, 64, 64,    │     18,496 │ max_pooling2d_24… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_116[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_117 (Conv2D) │ (None, 64, 64,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_117[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_25    │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_118 (Conv2D) │ (None, 32, 32,    │     73,856 │ max_pooling2d_25… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_118[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_119 (Conv2D) │ (None, 32, 32,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_119[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_26    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_120 (Conv2D) │ (None, 16, 16,    │    295,168 │ max_pooling2d_26… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_120[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_121 (Conv2D) │ (None, 16, 16,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_121[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_27    │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_122 (Conv2D) │ (None, 8, 8, 512) │  1,180,160 │ max_pooling2d_27… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_122[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_123 (Conv2D) │ (None, 8, 8, 512) │  2,359,808 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 512) │      2,048 │ conv2d_123[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 8, 8, 512) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_24 │ (None, 16, 16,    │    524,544 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_124 (Conv2D) │ (None, 16, 16,    │  1,179,904 │ concatenate_24[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_124[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_125 (Conv2D) │ (None, 16, 16,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_125[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_25 │ (None, 32, 32,    │    131,200 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_126 (Conv2D) │ (None, 32, 32,    │    295,040 │ concatenate_25[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_126[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_127 (Conv2D) │ (None, 32, 32,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_127[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_26 │ (None, 64, 64,    │     32,832 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_128 (Conv2D) │ (None, 64, 64,    │     73,792 │ concatenate_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_128[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_129 (Conv2D) │ (None, 64, 64,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_129[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_27 │ (None, 128, 128,  │      8,224 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_130 (Conv2D) │ (None, 128, 128,  │     18,464 │ concatenate_27[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_130[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_131 (Conv2D) │ (None, 128, 128,  │      9,248 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_131[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_132 (Conv2D) │ (None, 128, 128,  │        231 │ batch_normalizat… │
# │                     │ 7)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,772,071 (29.65 MB)
#  Trainable params: 7,766,183 (29.63 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
# 6. Training with callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-5, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

history = model.fit(
    X, Y,
    validation_split=0.2,
    epochs=500,
    batch_size=8,
    shuffle=True,
    callbacks=[reduce_lr, early_stop]
)
# Out:
# Epoch 1/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 48s 292ms/step - accuracy: 0.4685 - loss: 1.7019 - mean_iou: 0.1571 - val_accuracy: 0.5086 - val_loss: 1.5954 - val_mean_iou: 0.0872 - learning_rate: 0.0010
# Epoch 2/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.6130 - loss: 1.2756 - mean_iou: 0.2036 - val_accuracy: 0.6128 - val_loss: 1.4349 - val_mean_iou: 0.0894 - learning_rate: 0.0010
# Epoch 3/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.6597 - loss: 1.1329 - mean_iou: 0.2503 - val_accuracy: 0.1097 - val_loss: 52.9446 - val_mean_iou: 0.0315 - learning_rate: 0.0010
# Epoch 4/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.6524 - loss: 1.0870 - mean_iou: 0.2553 - val_accuracy: 0.4902 - val_loss: 1.6583 - val_mean_iou: 0.0787 - learning_rate: 0.0010
# Epoch 5/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.6565 - loss: 1.0600 - mean_iou: 0.2658 - val_accuracy: 0.6162 - val_loss: 1.5598 - val_mean_iou: 0.1127 - learning_rate: 0.0010
# Epoch 6/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.6613 - loss: 1.0136 - mean_iou: 0.2799 - val_accuracy: 0.6427 - val_loss: 1.3902 - val_mean_iou: 0.1854 - learning_rate: 0.0010
# Epoch 7/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.6750 - loss: 0.9601 - mean_iou: 0.2963 - val_accuracy: 0.6343 - val_loss: 1.3330 - val_mean_iou: 0.1889 - learning_rate: 0.0010
# Epoch 8/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.6754 - loss: 0.9486 - mean_iou: 0.2949 - val_accuracy: 0.6088 - val_loss: 1.2608 - val_mean_iou: 0.1439 - learning_rate: 0.0010
# Epoch 9/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7076 - loss: 0.8898 - mean_iou: 0.3163 - val_accuracy: 0.6890 - val_loss: 0.9709 - val_mean_iou: 0.3015 - learning_rate: 0.0010
# Epoch 10/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.6993 - loss: 0.8974 - mean_iou: 0.3033 - val_accuracy: 0.7495 - val_loss: 0.8032 - val_mean_iou: 0.3206 - learning_rate: 0.0010
# Epoch 11/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7085 - loss: 0.8563 - mean_iou: 0.3300 - val_accuracy: 0.7286 - val_loss: 0.9752 - val_mean_iou: 0.2648 - learning_rate: 0.0010
# Epoch 12/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7208 - loss: 0.8405 - mean_iou: 0.3395 - val_accuracy: 0.7473 - val_loss: 0.8882 - val_mean_iou: 0.2726 - learning_rate: 0.0010
# Epoch 13/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7031 - loss: 0.8802 - mean_iou: 0.3342 - val_accuracy: 0.7057 - val_loss: 0.8850 - val_mean_iou: 0.2955 - learning_rate: 0.0010
# Epoch 14/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7259 - loss: 0.8177 - mean_iou: 0.3696 - val_accuracy: 0.7171 - val_loss: 0.8386 - val_mean_iou: 0.3202 - learning_rate: 0.0010
# Epoch 15/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7196 - loss: 0.8186 - mean_iou: 0.3550 - val_accuracy: 0.7058 - val_loss: 0.9165 - val_mean_iou: 0.2619 - learning_rate: 0.0010
# Epoch 16/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.7241 - loss: 0.8172 - mean_iou: 0.3537 - val_accuracy: 0.7678 - val_loss: 0.7578 - val_mean_iou: 0.3311 - learning_rate: 0.0010
# Epoch 17/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7219 - loss: 0.8087 - mean_iou: 0.3578 - val_accuracy: 0.7585 - val_loss: 0.7508 - val_mean_iou: 0.3147 - learning_rate: 0.0010
# Epoch 18/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.7210 - loss: 0.8054 - mean_iou: 0.3722 - val_accuracy: 0.5096 - val_loss: 1.2919 - val_mean_iou: 0.1906 - learning_rate: 0.0010
# Epoch 19/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.7261 - loss: 0.8048 - mean_iou: 0.3534 - val_accuracy: 0.5445 - val_loss: 1.6399 - val_mean_iou: 0.3099 - learning_rate: 0.0010
# Epoch 20/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7366 - loss: 0.7714 - mean_iou: 0.3892 - val_accuracy: 0.8025 - val_loss: 0.6089 - val_mean_iou: 0.4113 - learning_rate: 0.0010
# Epoch 21/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.7427 - loss: 0.7584 - mean_iou: 0.3831 - val_accuracy: 0.7242 - val_loss: 0.8643 - val_mean_iou: 0.3652 - learning_rate: 0.0010
# Epoch 22/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.7362 - loss: 0.7867 - mean_iou: 0.3672 - val_accuracy: 0.5108 - val_loss: 1.4384 - val_mean_iou: 0.2686 - learning_rate: 0.0010
# Epoch 23/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7482 - loss: 0.7496 - mean_iou: 0.3711 - val_accuracy: 0.7252 - val_loss: 0.7963 - val_mean_iou: 0.3091 - learning_rate: 0.0010
# Epoch 24/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.7491 - loss: 0.7385 - mean_iou: 0.3788 - val_accuracy: 0.7964 - val_loss: 0.6189 - val_mean_iou: 0.4108 - learning_rate: 0.0010
# Epoch 25/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7359 - loss: 0.7620 - mean_iou: 0.3753 - val_accuracy: 0.7751 - val_loss: 0.7455 - val_mean_iou: 0.3567 - learning_rate: 0.0010
# Epoch 26/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.7490 - loss: 0.7273 - mean_iou: 0.4142 - val_accuracy: 0.7655 - val_loss: 0.6832 - val_mean_iou: 0.3463 - learning_rate: 0.0010
# Epoch 27/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7374 - loss: 0.7668 - mean_iou: 0.3766 - val_accuracy: 0.7651 - val_loss: 0.6674 - val_mean_iou: 0.3779 - learning_rate: 0.0010
# Epoch 28/500
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7486 - loss: 0.7268 - mean_iou: 0.3939
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7485 - loss: 0.7272 - mean_iou: 0.3943 - val_accuracy: 0.7776 - val_loss: 0.7091 - val_mean_iou: 0.4036 - learning_rate: 0.0010
# Epoch 29/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.7651 - loss: 0.7035 - mean_iou: 0.4334 - val_accuracy: 0.8168 - val_loss: 0.5710 - val_mean_iou: 0.4632 - learning_rate: 5.0000e-04
# Epoch 30/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.7835 - loss: 0.6412 - mean_iou: 0.4609 - val_accuracy: 0.8131 - val_loss: 0.5564 - val_mean_iou: 0.4651 - learning_rate: 5.0000e-04
# Epoch 31/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.7589 - loss: 0.7155 - mean_iou: 0.4481 - val_accuracy: 0.8146 - val_loss: 0.5763 - val_mean_iou: 0.4457 - learning_rate: 5.0000e-04
# Epoch 32/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7720 - loss: 0.6650 - mean_iou: 0.4663 - val_accuracy: 0.8100 - val_loss: 0.5849 - val_mean_iou: 0.4430 - learning_rate: 5.0000e-04
# Epoch 33/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.7777 - loss: 0.6533 - mean_iou: 0.4644 - val_accuracy: 0.8135 - val_loss: 0.5740 - val_mean_iou: 0.4448 - learning_rate: 5.0000e-04
# Epoch 34/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.7879 - loss: 0.6310 - mean_iou: 0.4483 - val_accuracy: 0.8166 - val_loss: 0.5854 - val_mean_iou: 0.4691 - learning_rate: 5.0000e-04
# Epoch 35/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.7758 - loss: 0.6562 - mean_iou: 0.4669 - val_accuracy: 0.8025 - val_loss: 0.6235 - val_mean_iou: 0.4195 - learning_rate: 5.0000e-04
# Epoch 36/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - accuracy: 0.7843 - loss: 0.6286 - mean_iou: 0.4879 - val_accuracy: 0.8149 - val_loss: 0.5608 - val_mean_iou: 0.4373 - learning_rate: 5.0000e-04
# Epoch 37/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.7730 - loss: 0.6767 - mean_iou: 0.4373 - val_accuracy: 0.8150 - val_loss: 0.5667 - val_mean_iou: 0.4652 - learning_rate: 5.0000e-04
# Epoch 38/500
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7846 - loss: 0.6378 - mean_iou: 0.4748
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7845 - loss: 0.6382 - mean_iou: 0.4745 - val_accuracy: 0.7395 - val_loss: 0.7376 - val_mean_iou: 0.4214 - learning_rate: 5.0000e-04
# Epoch 39/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - accuracy: 0.7843 - loss: 0.6483 - mean_iou: 0.4534 - val_accuracy: 0.8173 - val_loss: 0.5303 - val_mean_iou: 0.4805 - learning_rate: 2.5000e-04
# Epoch 40/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.7776 - loss: 0.6472 - mean_iou: 0.4895 - val_accuracy: 0.8206 - val_loss: 0.5407 - val_mean_iou: 0.4630 - learning_rate: 2.5000e-04
# Epoch 41/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.7802 - loss: 0.6394 - mean_iou: 0.4660 - val_accuracy: 0.8267 - val_loss: 0.5154 - val_mean_iou: 0.4739 - learning_rate: 2.5000e-04
# Epoch 42/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.7869 - loss: 0.6162 - mean_iou: 0.4726 - val_accuracy: 0.8300 - val_loss: 0.5164 - val_mean_iou: 0.4780 - learning_rate: 2.5000e-04
# Epoch 43/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.7974 - loss: 0.6018 - mean_iou: 0.4907 - val_accuracy: 0.8299 - val_loss: 0.5072 - val_mean_iou: 0.4847 - learning_rate: 2.5000e-04
# Epoch 44/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.8010 - loss: 0.5888 - mean_iou: 0.5015 - val_accuracy: 0.7895 - val_loss: 0.6083 - val_mean_iou: 0.3962 - learning_rate: 2.5000e-04
# Epoch 45/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.7994 - loss: 0.5842 - mean_iou: 0.4981 - val_accuracy: 0.8250 - val_loss: 0.5122 - val_mean_iou: 0.4792 - learning_rate: 2.5000e-04
# Epoch 46/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.7820 - loss: 0.6332 - mean_iou: 0.4852 - val_accuracy: 0.8319 - val_loss: 0.5065 - val_mean_iou: 0.4918 - learning_rate: 2.5000e-04
# Epoch 47/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8109 - loss: 0.5537 - mean_iou: 0.5128 - val_accuracy: 0.8216 - val_loss: 0.5273 - val_mean_iou: 0.4833 - learning_rate: 2.5000e-04
# Epoch 48/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8045 - loss: 0.5773 - mean_iou: 0.5107 - val_accuracy: 0.7906 - val_loss: 0.6635 - val_mean_iou: 0.4476 - learning_rate: 2.5000e-04
# Epoch 49/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8110 - loss: 0.5736 - mean_iou: 0.4911 - val_accuracy: 0.8307 - val_loss: 0.5044 - val_mean_iou: 0.4842 - learning_rate: 2.5000e-04
# Epoch 50/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8119 - loss: 0.5673 - mean_iou: 0.5032 - val_accuracy: 0.8255 - val_loss: 0.5185 - val_mean_iou: 0.4780 - learning_rate: 2.5000e-04
# Epoch 51/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8056 - loss: 0.5805 - mean_iou: 0.5202 - val_accuracy: 0.8297 - val_loss: 0.5017 - val_mean_iou: 0.4836 - learning_rate: 2.5000e-04
# Epoch 52/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8066 - loss: 0.5829 - mean_iou: 0.4984 - val_accuracy: 0.8203 - val_loss: 0.5361 - val_mean_iou: 0.4764 - learning_rate: 2.5000e-04
# Epoch 53/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.8145 - loss: 0.5670 - mean_iou: 0.5438 - val_accuracy: 0.8206 - val_loss: 0.5397 - val_mean_iou: 0.4706 - learning_rate: 2.5000e-04
# Epoch 54/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.8010 - loss: 0.5939 - mean_iou: 0.5114 - val_accuracy: 0.8284 - val_loss: 0.5134 - val_mean_iou: 0.4766 - learning_rate: 2.5000e-04
# Epoch 55/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.7980 - loss: 0.5965 - mean_iou: 0.4686 - val_accuracy: 0.8298 - val_loss: 0.5033 - val_mean_iou: 0.4863 - learning_rate: 2.5000e-04
# Epoch 56/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.8062 - loss: 0.5902 - mean_iou: 0.5133 - val_accuracy: 0.7979 - val_loss: 0.6033 - val_mean_iou: 0.4568 - learning_rate: 2.5000e-04
# Epoch 57/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8109 - loss: 0.5666 - mean_iou: 0.5146 - val_accuracy: 0.8255 - val_loss: 0.5179 - val_mean_iou: 0.4827 - learning_rate: 2.5000e-04
# Epoch 58/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8131 - loss: 0.5627 - mean_iou: 0.5244 - val_accuracy: 0.8219 - val_loss: 0.5488 - val_mean_iou: 0.4778 - learning_rate: 2.5000e-04
# Epoch 59/500
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7984 - loss: 0.5897 - mean_iou: 0.5019
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.7986 - loss: 0.5894 - mean_iou: 0.5024 - val_accuracy: 0.7631 - val_loss: 0.7030 - val_mean_iou: 0.4453 - learning_rate: 2.5000e-04
# Epoch 60/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8139 - loss: 0.5570 - mean_iou: 0.5173 - val_accuracy: 0.8323 - val_loss: 0.5042 - val_mean_iou: 0.4938 - learning_rate: 1.2500e-04
# Epoch 61/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8178 - loss: 0.5380 - mean_iou: 0.5349 - val_accuracy: 0.8278 - val_loss: 0.5110 - val_mean_iou: 0.4908 - learning_rate: 1.2500e-04
# Epoch 62/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8189 - loss: 0.5519 - mean_iou: 0.5517 - val_accuracy: 0.8267 - val_loss: 0.5031 - val_mean_iou: 0.4786 - learning_rate: 1.2500e-04
# Epoch 63/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.8182 - loss: 0.5404 - mean_iou: 0.5248 - val_accuracy: 0.8233 - val_loss: 0.5301 - val_mean_iou: 0.4842 - learning_rate: 1.2500e-04
# Epoch 64/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8203 - loss: 0.5405 - mean_iou: 0.5414 - val_accuracy: 0.8293 - val_loss: 0.4951 - val_mean_iou: 0.5001 - learning_rate: 1.2500e-04
# Epoch 65/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8293 - loss: 0.5138 - mean_iou: 0.5684 - val_accuracy: 0.8225 - val_loss: 0.5218 - val_mean_iou: 0.4916 - learning_rate: 1.2500e-04
# Epoch 66/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8248 - loss: 0.5326 - mean_iou: 0.5449 - val_accuracy: 0.8347 - val_loss: 0.4880 - val_mean_iou: 0.4997 - learning_rate: 1.2500e-04
# Epoch 67/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8136 - loss: 0.5557 - mean_iou: 0.5163 - val_accuracy: 0.8221 - val_loss: 0.5234 - val_mean_iou: 0.4820 - learning_rate: 1.2500e-04
# Epoch 68/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8182 - loss: 0.5522 - mean_iou: 0.5262 - val_accuracy: 0.8224 - val_loss: 0.5178 - val_mean_iou: 0.4911 - learning_rate: 1.2500e-04
# Epoch 69/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8163 - loss: 0.5374 - mean_iou: 0.5320 - val_accuracy: 0.8306 - val_loss: 0.5002 - val_mean_iou: 0.5049 - learning_rate: 1.2500e-04
# Epoch 70/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.8277 - loss: 0.5150 - mean_iou: 0.5503 - val_accuracy: 0.8314 - val_loss: 0.4945 - val_mean_iou: 0.4983 - learning_rate: 1.2500e-04
# Epoch 71/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8328 - loss: 0.5031 - mean_iou: 0.5389 - val_accuracy: 0.8097 - val_loss: 0.5505 - val_mean_iou: 0.4817 - learning_rate: 1.2500e-04
# Epoch 72/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8290 - loss: 0.5131 - mean_iou: 0.5656 - val_accuracy: 0.8337 - val_loss: 0.4941 - val_mean_iou: 0.4938 - learning_rate: 1.2500e-04
# Epoch 73/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8085 - loss: 0.5751 - mean_iou: 0.5416 - val_accuracy: 0.8313 - val_loss: 0.5001 - val_mean_iou: 0.4905 - learning_rate: 1.2500e-04
# Epoch 74/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8289 - loss: 0.5298 - mean_iou: 0.5351 - val_accuracy: 0.8352 - val_loss: 0.4877 - val_mean_iou: 0.5100 - learning_rate: 1.2500e-04
# Epoch 75/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8342 - loss: 0.4956 - mean_iou: 0.5469 - val_accuracy: 0.8306 - val_loss: 0.5021 - val_mean_iou: 0.5038 - learning_rate: 1.2500e-04
# Epoch 76/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8398 - loss: 0.4852 - mean_iou: 0.5770 - val_accuracy: 0.8284 - val_loss: 0.5039 - val_mean_iou: 0.4881 - learning_rate: 1.2500e-04
# Epoch 77/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8233 - loss: 0.5184 - mean_iou: 0.5547 - val_accuracy: 0.8284 - val_loss: 0.5059 - val_mean_iou: 0.4980 - learning_rate: 1.2500e-04
# Epoch 78/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8268 - loss: 0.5152 - mean_iou: 0.5379 - val_accuracy: 0.8237 - val_loss: 0.5155 - val_mean_iou: 0.5017 - learning_rate: 1.2500e-04
# Epoch 79/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.8337 - loss: 0.5001 - mean_iou: 0.5668 - val_accuracy: 0.8208 - val_loss: 0.5254 - val_mean_iou: 0.4966 - learning_rate: 1.2500e-04
# Epoch 80/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.8323 - loss: 0.5016 - mean_iou: 0.5664 - val_accuracy: 0.8319 - val_loss: 0.4898 - val_mean_iou: 0.5109 - learning_rate: 1.2500e-04
# Epoch 81/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8233 - loss: 0.5234 - mean_iou: 0.5279 - val_accuracy: 0.8278 - val_loss: 0.4990 - val_mean_iou: 0.5053 - learning_rate: 1.2500e-04
# Epoch 82/500
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8234 - loss: 0.5259 - mean_iou: 0.5491
# Epoch 82: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8235 - loss: 0.5257 - mean_iou: 0.5492 - val_accuracy: 0.8256 - val_loss: 0.5044 - val_mean_iou: 0.4937 - learning_rate: 1.2500e-04
# Epoch 83/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.8353 - loss: 0.4934 - mean_iou: 0.5730 - val_accuracy: 0.8341 - val_loss: 0.4869 - val_mean_iou: 0.5135 - learning_rate: 6.2500e-05
# Epoch 84/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8339 - loss: 0.4986 - mean_iou: 0.5800 - val_accuracy: 0.8336 - val_loss: 0.4895 - val_mean_iou: 0.5053 - learning_rate: 6.2500e-05
# Epoch 85/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8300 - loss: 0.4936 - mean_iou: 0.5597 - val_accuracy: 0.8315 - val_loss: 0.4967 - val_mean_iou: 0.5077 - learning_rate: 6.2500e-05
# Epoch 86/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8377 - loss: 0.4877 - mean_iou: 0.5559 - val_accuracy: 0.8345 - val_loss: 0.4877 - val_mean_iou: 0.5114 - learning_rate: 6.2500e-05
# Epoch 87/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8333 - loss: 0.5011 - mean_iou: 0.5736 - val_accuracy: 0.8302 - val_loss: 0.4960 - val_mean_iou: 0.5134 - learning_rate: 6.2500e-05
# Epoch 88/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8445 - loss: 0.4719 - mean_iou: 0.5589 - val_accuracy: 0.8349 - val_loss: 0.4864 - val_mean_iou: 0.5121 - learning_rate: 6.2500e-05
# Epoch 89/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8249 - loss: 0.5190 - mean_iou: 0.5439 - val_accuracy: 0.8363 - val_loss: 0.4853 - val_mean_iou: 0.5121 - learning_rate: 6.2500e-05
# Epoch 90/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.8454 - loss: 0.4621 - mean_iou: 0.5639 - val_accuracy: 0.8371 - val_loss: 0.4846 - val_mean_iou: 0.5145 - learning_rate: 6.2500e-05
# Epoch 91/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.8365 - loss: 0.4996 - mean_iou: 0.5960 - val_accuracy: 0.8323 - val_loss: 0.4918 - val_mean_iou: 0.5135 - learning_rate: 6.2500e-05
# Epoch 92/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.8427 - loss: 0.4787 - mean_iou: 0.5814 - val_accuracy: 0.8337 - val_loss: 0.4892 - val_mean_iou: 0.5072 - learning_rate: 6.2500e-05
# Epoch 93/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8555 - loss: 0.4474 - mean_iou: 0.5694 - val_accuracy: 0.8327 - val_loss: 0.4924 - val_mean_iou: 0.5088 - learning_rate: 6.2500e-05
# Epoch 94/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8336 - loss: 0.4946 - mean_iou: 0.5856 - val_accuracy: 0.8350 - val_loss: 0.4884 - val_mean_iou: 0.5126 - learning_rate: 6.2500e-05
# Epoch 95/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8333 - loss: 0.4995 - mean_iou: 0.5720 - val_accuracy: 0.8311 - val_loss: 0.4914 - val_mean_iou: 0.5045 - learning_rate: 6.2500e-05
# Epoch 96/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.8429 - loss: 0.4800 - mean_iou: 0.5903 - val_accuracy: 0.8302 - val_loss: 0.4980 - val_mean_iou: 0.5092 - learning_rate: 6.2500e-05
# Epoch 97/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.8338 - loss: 0.4980 - mean_iou: 0.5590 - val_accuracy: 0.8344 - val_loss: 0.4882 - val_mean_iou: 0.5117 - learning_rate: 6.2500e-05
# Epoch 98/500
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8481 - loss: 0.4645 - mean_iou: 0.5829
# Epoch 98: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.8477 - loss: 0.4656 - mean_iou: 0.5827 - val_accuracy: 0.8323 - val_loss: 0.4898 - val_mean_iou: 0.5101 - learning_rate: 6.2500e-05
# Epoch 99/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8331 - loss: 0.5089 - mean_iou: 0.5722 - val_accuracy: 0.8347 - val_loss: 0.4864 - val_mean_iou: 0.5111 - learning_rate: 3.1250e-05
# Epoch 100/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8370 - loss: 0.4910 - mean_iou: 0.5963 - val_accuracy: 0.8328 - val_loss: 0.4917 - val_mean_iou: 0.5119 - learning_rate: 3.1250e-05
# Epoch 101/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.8327 - loss: 0.5157 - mean_iou: 0.5860 - val_accuracy: 0.8353 - val_loss: 0.4857 - val_mean_iou: 0.5114 - learning_rate: 3.1250e-05
# Epoch 102/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8529 - loss: 0.4484 - mean_iou: 0.5934 - val_accuracy: 0.8344 - val_loss: 0.4874 - val_mean_iou: 0.5161 - learning_rate: 3.1250e-05
# Epoch 103/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8482 - loss: 0.4532 - mean_iou: 0.5753 - val_accuracy: 0.8337 - val_loss: 0.4898 - val_mean_iou: 0.5122 - learning_rate: 3.1250e-05
# Epoch 104/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.8378 - loss: 0.4896 - mean_iou: 0.5899 - val_accuracy: 0.8351 - val_loss: 0.4876 - val_mean_iou: 0.5125 - learning_rate: 3.1250e-05
# Epoch 105/500
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.8436 - loss: 0.4678 - mean_iou: 0.5881 - val_accuracy: 0.8336 - val_loss: 0.4865 - val_mean_iou: 0.5120 - learning_rate: 3.1250e-05
# Epoch 105: early stopping
# Restoring model weights from the end of the best epoch: 90.

# %%
# 7. Visualize predictions helper
def show_pred(i):
    img = X[i]
    true_mask = class_to_rgb(np.argmax(Y[i], axis=-1))
    pred = model.predict(np.expand_dims(img, 0), verbose=0)[0]
    pred_mask = class_to_rgb(np.argmax(pred, axis=-1))

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title('Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask)
    plt.title('True Mask')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask)
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.show()

print("Showing predictions for 3 random images:")
for i in np.random.choice(len(X), 3, replace=False):
    show_pred(i)

# 8. Save the model
model.save('deepglobe_unet_miou_improved.keras')

# For Colab: download saved model (optional)
try:
    from google.colab import files
    files.download('deepglobe_unet_miou_improved.keras')
except:
    print("File download skipped (not running in Colab).")
# Out:
# Showing predictions for 3 random images:
