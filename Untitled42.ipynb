# %% [markdown]
# <a href="https://colab.research.google.com/github/yamrajkhadka/Land-Cover-Classification-from-Satellite-Images-using-U-Net-on-the-DeepGlobe-Dataset/blob/main/Untitled42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install kaggle
# Set up Kaggle API credentials
import os
os.environ['KAGGLE_USERNAME'] = 'yamrajkhadka01'
os.environ['KAGGLE_KEY'] = '/content/kaggle (5).json'
# Download the dataset
# !kaggle datasets download -d balraj98/deepglobe-land-cover-classification-dataset -p /content/
# Unzip the dataset
# !unzip -q /content/deepglobe-land-cover-classification-dataset.zip -d /content/deepglobe_dataset/
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Dataset URL: https://www.kaggle.com/datasets/balraj98/deepglobe-land-cover-classification-dataset
# License(s): other
# deepglobe-land-cover-classification-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# replace /content/deepglobe_dataset/class_dict.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import albumentations as A

# 1. Load Class Mapping
CLASS_DICT_CSV = '/content/deepglobe_dataset/class_dict.csv'
assert os.path.exists(CLASS_DICT_CSV), "class_dict.csv not found!"

class_dict = pd.read_csv(CLASS_DICT_CSV)
color2class = {(row['r'], row['g'], row['b']): idx for idx, row in class_dict.iterrows()}
NUM_CLASSES = len(class_dict)

def rgb_to_class(mask_rgb):
    h, w, _ = mask_rgb.shape
    mask_class = np.zeros((h, w), dtype=np.uint8)
    for color, class_idx in color2class.items():
        matches = np.all(mask_rgb == color, axis=-1)
        mask_class[matches] = class_idx
    return mask_class

def class_to_rgb(mask_class):
    h, w = mask_class.shape
    mask_rgb = np.zeros((h, w, 3), dtype=np.uint8)
    for color, class_idx in color2class.items():
        mask_rgb[mask_class == class_idx] = color
    return mask_rgb

# 2. Load Dataset and Apply Augmentations
TRAIN_IMG_DIR = '/content/deepglobe_dataset/train'
assert os.path.exists(TRAIN_IMG_DIR), "Train directory not found!"

IMG_SIZE = (224, 224)  # updated from 216 to 224
img_ids = [f[:-8] for f in os.listdir(TRAIN_IMG_DIR) if f.endswith('_sat.jpg')]
N = len(img_ids)

transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.3),
    A.RandomBrightnessContrast(p=0.3),
    A.Affine(rotate=(-15, 15), scale=(0.9, 1.1), translate_percent=0.1, p=0.5),
])

X, Y = [], []
for img_id in img_ids[:N]:
    img_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_sat.jpg")
    mask_path = os.path.join(TRAIN_IMG_DIR, f"{img_id}_mask.png")

    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    mask = cv2.imread(mask_path)
    mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)

    augmented = transform(image=img, mask=mask)
    img = cv2.resize(augmented['image'], IMG_SIZE)
    mask = cv2.resize(augmented['mask'], IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    img = img / 255.0
    mask_class = rgb_to_class(mask)
    mask_onehot = to_categorical(mask_class, num_classes=NUM_CLASSES)

    X.append(img)
    Y.append(mask_onehot)

X = np.array(X, dtype=np.float32)
Y = np.array(Y, dtype=np.float32)
print(f"X: {X.shape} Y: {Y.shape}")

# 3. Compute Class Weights
flat_mask = np.argmax(Y, axis=-1).reshape(-1)
class_counts = np.bincount(flat_mask, minlength=NUM_CLASSES)
class_weights = class_counts.max() / (class_counts + 1e-6)
class_weights = class_weights / class_weights.sum() * NUM_CLASSES
print("Class weights:", class_weights)

# 4. Focal Tversky Loss
def focal_tversky_loss(alpha=0.7, beta=0.3, gamma=0.75):
    def loss_fn(y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        TP = tf.reduce_sum(y_true * y_pred, axis=[1,2])
        FP = tf.reduce_sum((1 - y_true) * y_pred, axis=[1,2])
        FN = tf.reduce_sum(y_true * (1 - y_pred), axis=[1,2])

        tversky = (TP + 1e-6) / (TP + alpha * FP + beta * FN + 1e-6)
        focal_loss = tf.pow((1 - tversky), gamma)
        return tf.reduce_mean(focal_loss)
    return loss_fn

loss_fn = focal_tversky_loss()

# 5. Mean IoU Metric
class MeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes, name='mean_iou', **kwargs):
        super().__init__(num_classes=num_classes, name=name, **kwargs)
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.argmax(y_true, axis=-1)
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# 6. Build U-Net Model
def build_unet(input_shape=(224, 224, 3), num_classes=NUM_CLASSES):
    def conv_block(x, filters):
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        x = Conv2D(filters, 3, padding='same', activation='relu')(x)
        x = BatchNormalization()(x)
        return x

    inputs = Input(input_shape)
    c1 = conv_block(inputs, 32); p1 = MaxPooling2D()(c1)
    c2 = conv_block(p1, 64); p2 = MaxPooling2D()(c2)
    c3 = conv_block(p2, 128); p3 = MaxPooling2D()(c3)
    c4 = conv_block(p3, 256); p4 = MaxPooling2D()(c4)
    b = conv_block(p4, 512); b = Dropout(0.4)(b)
    u1 = Conv2DTranspose(256, 2, strides=2, padding='same')(b); u1 = concatenate([u1, c4]); c5 = conv_block(u1, 256)
    u2 = Conv2DTranspose(128, 2, strides=2, padding='same')(c5); u2 = concatenate([u2, c3]); c6 = conv_block(u2, 128)
    u3 = Conv2DTranspose(64, 2, strides=2, padding='same')(c6); u3 = concatenate([u3, c2]); c7 = conv_block(u3, 64)
    u4 = Conv2DTranspose(32, 2, strides=2, padding='same')(c7); u4 = concatenate([u4, c1]); c8 = conv_block(u4, 32)
    outputs = Conv2D(num_classes, 1, activation='softmax')(c8)
    return Model(inputs, outputs)

model = build_unet()
model.compile(optimizer='adam', loss=loss_fn, metrics=[MeanIoU(NUM_CLASSES)])
model.summary()

# 7. Training with Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=8, min_lr=1e-5, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1)

history = model.fit(
    X, Y,
    validation_split=0.2,
    epochs=200,
    batch_size=8,
    shuffle=True,
    callbacks=[reduce_lr, early_stop],
    verbose=1
)

# 8. Plot Per-Class IoU
preds = model.predict(X)
preds_class = np.argmax(preds, axis=-1)
true_class = np.argmax(Y, axis=-1)

ious = []
for i in range(NUM_CLASSES):
    intersection = np.logical_and(preds_class == i, true_class == i).sum()
    union = np.logical_or(preds_class == i, true_class == i).sum()
    iou = intersection / (union + 1e-6)
    ious.append(iou)
    print(f"Class {i} IoU: {iou:.4f}")

print("Mean IoU:", np.mean(ious))
# Out:
# X: (803, 224, 224, 3) Y: (803, 224, 224, 7)
# Class weights: [0.7946775  0.14716869 0.99668641 0.76578409 2.50711468 1.01677075
#  0.77179788]
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d
200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.7130 - mean_iou: 0.5050 - val_loss: 0.7299 - val_mean_iou: 0.4325 - learning_rate: 0.0010
# Epoch 26/200
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.7146 - mean_iou: 0.5012
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - loss: 0.7145 - mean_iou: 0.5012 - val_loss: 0.7642 - val_mean_iou: 0.3477 - learning_rate: 0.0010
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.7049 - mean_iou: 0.5121 - val_loss: 0.7243 - val_mean_iou: 0.4543 - learning_rate: 5.0000e-04
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 150ms/step - loss: 0.7009 - mean_iou: 0.5225 - val_loss: 0.7335 - val_mean_iou: 0.4267 - learning_rate: 5.0000e-04
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - loss: 0.7022 - mean_iou: 0.5158 - val_loss: 0.7103 - val_mean_iou: 0.4739 - learning_rate: 5.0000e-04
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6895 - mean_iou: 0.5224 - val_loss: 0.7057 - val_mean_iou: 0.4985 - learning_rate: 5.0000e-04
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: 0.6890 - mean_iou: 0.5339 - val_loss: 0.7022 - val_mean_iou: 0.4672 - learning_rate: 5.0000e-04
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.7030 - mean_iou: 0.5160 - val_loss: 0.6972 - val_mean_iou: 0.5255 - learning_rate: 5.0000e-04
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.6980 - mean_iou: 0.5179 - val_loss: 0.6965 - val_mean_iou: 0.5286 - learning_rate: 5.0000e-04
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - loss: 0.6932 - mean_iou: 0.5220 - val_loss: 0.7341 - val_mean_iou: 0.4623 - learning_rate: 5.0000e-04
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 149ms/step - loss: 0.6926 - mean_iou: 0.5212 - val_loss: 0.7059 - val_mean_iou: 0.4900 - learning_rate: 5.0000e-04
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - loss: 0.6971 - mean_iou: 0.5216 - val_loss: 0.7014 - val_mean_iou: 0.5211 - learning_rate: 5.0000e-04
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 147ms/step - loss: 0.6889 - mean_iou: 0.5437 - val_loss: 0.7008 - val_mean_iou: 0.4907 - learning_rate: 5.0000e-04
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - loss: 0.6799 - mean_iou: 0.5548 - val_loss: 0.6892 - val_mean_iou: 0.5467 - learning_rate: 5.0000e-04
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - loss: 0.6898 - mean_iou: 0.5442 - val_loss: 0.6890 - val_mean_iou: 0.5491 - learning_rate: 5.0000e-04
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 150ms/step - loss: 0.6765 - mean_iou: 0.5437 - val_loss: 0.6852 - val_mean_iou: 0.5623 - learning_rate: 5.0000e-04
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - loss: 0.6825 - mean_iou: 0.5606 - val_loss: 0.6937 - val_mean_iou: 0.5338 - learning_rate: 5.0000e-04
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6862 - mean_iou: 0.5565 - val_loss: 0.7030 - val_mean_iou: 0.4901 - learning_rate: 5.0000e-04
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - loss: 0.6874 - mean_iou: 0.5515 - val_loss: 0.6872 - val_mean_iou: 0.5587 - learning_rate: 5.0000e-04
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6865 - mean_iou: 0.5425 - val_loss: 0.6882 - val_mean_iou: 0.5479 - learning_rate: 5.0000e-04
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - loss: 0.6807 - mean_iou: 0.5584 - val_loss: 0.7196 - val_mean_iou: 0.4527 - learning_rate: 5.0000e-04
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6845 - mean_iou: 0.5433 - val_loss: 0.7034 - val_mean_iou: 0.5195 - learning_rate: 5.0000e-04
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - loss: 0.6935 - mean_iou: 0.5442 - val_loss: 0.6828 - val_mean_iou: 0.5531 - learning_rate: 5.0000e-04
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.6777 - mean_iou: 0.5463 - val_loss: 0.6884 - val_mean_iou: 0.5486 - learning_rate: 5.0000e-04
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - loss: 0.6800 - mean_iou: 0.5556 - val_loss: 0.6866 - val_mean_iou: 0.5497 - learning_rate: 5.0000e-04
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - loss: 0.6822 - mean_iou: 0.5752 - val_loss: 0.6869 - val_mean_iou: 0.5450 - learning_rate: 5.0000e-04
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - loss: 0.6808 - mean_iou: 0.5565 - val_loss: 0.7017 - val_mean_iou: 0.4819 - learning_rate: 5.0000e-04
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6757 - mean_iou: 0.5727 - val_loss: 0.6883 - val_mean_iou: 0.5532 - learning_rate: 5.0000e-04
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.6788 - mean_iou: 0.5680 - val_loss: 0.6893 - val_mean_iou: 0.5454 - learning_rate: 5.0000e-04
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - loss: 0.6703 - mean_iou: 0.5599 - val_loss: 0.6873 - val_mean_iou: 0.5730 - learning_rate: 5.0000e-04
# Epoch 55/200
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.6770 - mean_iou: 0.5757
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - loss: 0.6770 - mean_iou: 0.5755 - val_loss: 0.6841 - val_mean_iou: 0.5636 - learning_rate: 5.0000e-04
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - loss: 0.6703 - mean_iou: 0.5813 - val_loss: 0.6788 - val_mean_iou: 0.5767 - learning_rate: 2.5000e-04
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - loss: 0.6624 - mean_iou: 0.5914 - val_loss: 0.6829 - val_mean_iou: 0.5700 - learning_rate: 2.5000e-04
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - loss: 0.6661 - mean_iou: 0.5873 - val_loss: 0.6833 - val_mean_iou: 0.5445 - learning_rate: 2.5000e-04
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 153ms/step - loss: 0.6757 - mean_iou: 0.5727 - val_loss: 0.6890 - val_mean_iou: 0.5354 - learning_rate: 2.5000e-04
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6647 - mean_iou: 0.5864 - val_loss: 0.6789 - val_mean_iou: 0.5793 - learning_rate: 2.5000e-04
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - loss: 0.6699 - mean_iou: 0.5717 - val_loss: 0.6812 - val_mean_iou: 0.5758 - learning_rate: 2.5000e-04
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - loss: 0.6588 - mean_iou: 0.5876 - val_loss: 0.6781 - val_mean_iou: 0.5856 - learning_rate: 2.5000e-04
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 150ms/step - loss: 0.6585 - mean_iou: 0.5967 - val_loss: 0.6898 - val_mean_iou: 0.5475 - learning_rate: 2.5000e-04
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - loss: 0.6673 - mean_iou: 0.6075 - val_loss: 0.6764 - val_mean_iou: 0.5826 - learning_rate: 2.5000e-04
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - loss: 0.6561 - mean_iou: 0.5954 - val_loss: 0.6770 - val_mean_iou: 0.5909 - learning_rate: 2.5000e-04
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - loss: 0.6679 - mean_iou: 0.6038 - val_loss: 0.6779 - val_mean_iou: 0.5771 - learning_rate: 2.5000e-04
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 155ms/step - loss: 0.6671 - mean_iou: 0.5928 - val_loss: 0.6766 - val_mean_iou: 0.5930 - learning_rate: 2.5000e-04
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - loss: 0.6648 - mean_iou: 0.5888 - val_loss: 0.6868 - val_mean_iou: 0.5450 - learning_rate: 2.5000e-04
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6669 - mean_iou: 0.5945 - val_loss: 0.6776 - val_mean_iou: 0.5866 - learning_rate: 2.5000e-04
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - loss: 0.6569 - mean_iou: 0.6117 - val_loss: 0.6795 - val_mean_iou: 0.5673 - learning_rate: 2.5000e-04
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - loss: 0.6580 - mean_iou: 0.6107 - val_loss: 0.6758 - val_mean_iou: 0.5942 - learning_rate: 2.5000e-04
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - loss: 0.6586 - mean_iou: 0.6039 - val_loss: 0.6734 - val_mean_iou: 0.5902 - learning_rate: 2.5000e-04
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6586 - mean_iou: 0.6009 - val_loss: 0.6840 - val_mean_iou: 0.5585 - learning_rate: 2.5000e-04
# Epoch 74/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - loss: 0.6596 - mean_iou: 0.5914 - val_loss: 0.6748 - val_mean_iou: 0.5879 - learning_rate: 2.5000e-04
# Epoch 75/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - loss: 0.6571 - mean_iou: 0.6098 - val_loss: 0.6833 - val_mean_iou: 0.5668 - learning_rate: 2.5000e-04
# Epoch 76/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 158ms/step - loss: 0.6545 - mean_iou: 0.5941 - val_loss: 0.6828 - val_mean_iou: 0.5670 - learning_rate: 2.5000e-04
# Epoch 77/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - loss: 0.6543 - mean_iou: 0.6041 - val_loss: 0.6755 - val_mean_iou: 0.5990 - learning_rate: 2.5000e-04
# Epoch 78/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6517 - mean_iou: 0.6066 - val_loss: 0.6790 - val_mean_iou: 0.5836 - learning_rate: 2.5000e-04
# Epoch 79/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 157ms/step - loss: 0.6602 - mean_iou: 0.6103 - val_loss: 0.6805 - val_mean_iou: 0.5962 - learning_rate: 2.5000e-04
# Epoch 80/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 160ms/step - loss: 0.6536 - mean_iou: 0.6207 - val_loss: 0.6733 - val_mean_iou: 0.5967 - learning_rate: 2.5000e-04
# Epoch 81/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - loss: 0.6569 - mean_iou: 0.6086 - val_loss: 0.6964 - val_mean_iou: 0.5423 - learning_rate: 2.5000e-04
# Epoch 82/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6550 - mean_iou: 0.6079 - val_loss: 0.6753 - val_mean_iou: 0.5836 - learning_rate: 2.5000e-04
# Epoch 83/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - loss: 0.6573 - mean_iou: 0.5946 - val_loss: 0.6807 - val_mean_iou: 0.5667 - learning_rate: 2.5000e-04
# Epoch 84/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - loss: 0.6525 - mean_iou: 0.6180 - val_loss: 0.6746 - val_mean_iou: 0.5947 - learning_rate: 2.5000e-04
# Epoch 85/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - loss: 0.6508 - mean_iou: 0.6183 - val_loss: 0.6808 - val_mean_iou: 0.5871 - learning_rate: 2.5000e-04
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - loss: 0.6485 - mean_iou: 0.6054 - val_loss: 0.6776 - val_mean_iou: 0.5911 - learning_rate: 2.5000e-04
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - loss: 0.6508 - mean_iou: 0.5974 - val_loss: 0.6797 - val_mean_iou: 0.5755 - learning_rate: 2.5000e-04
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.6477 - mean_iou: 0.6180
# Epoch 88: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - loss: 0.6477 - mean_iou: 0.6180 - val_loss: 0.6884 - val_mean_iou: 0.5280 - learning_rate: 2.5000e-04
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6537 - mean_iou: 0.5983 - val_loss: 0.6792 - val_mean_iou: 0.5645 - learning_rate: 1.2500e-04
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - loss: 0.6468 - mean_iou: 0.6276 - val_loss: 0.6825 - val_mean_iou: 0.5651 - learning_rate: 1.2500e-04
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6430 - mean_iou: 0.6306 - val_loss: 0.6820 - val_mean_iou: 0.5735 - learning_rate: 1.2500e-04
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - loss: 0.6471 - mean_iou: 0.6220 - val_loss: 0.6746 - val_mean_iou: 0.5967 - learning_rate: 1.2500e-04
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - loss: 0.6390 - mean_iou: 0.6337 - val_loss: 0.6765 - val_mean_iou: 0.5969 - learning_rate: 1.2500e-04
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - loss: 0.6430 - mean_iou: 0.6298 - val_loss: 0.6756 - val_mean_iou: 0.5991 - learning_rate: 1.2500e-04
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - loss: 0.6473 - mean_iou: 0.6155 - val_loss: 0.6742 - val_mean_iou: 0.5941 - learning_rate: 1.2500e-04
# Epoch 95: early stopping
# Restoring model weights from the end of the best epoch: 80.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 20s 304ms/step
# Class 0 IoU: 0.6842
# Class 1 IoU: 0.7931
# Class 2 IoU: 0.2277
# Class 3 IoU: 0.6496
# Class 4 IoU: 0.6326
# Class 5 IoU: 0.4692
# Class 6 IoU: 0.9886
# Mean IoU: 0.635005474649863

# %%
# 7. Visualize predictions helper
def show_pred(i):
    img = X[i]
    true_mask = class_to_rgb(np.argmax(Y[i], axis=-1))
    pred = model.predict(np.expand_dims(img, 0), verbose=0)[0]
    pred_mask = class_to_rgb(np.argmax(pred, axis=-1))

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title('Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(true_mask)
    plt.title('True Mask')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask)
    plt.title('Predicted Mask')
    plt.axis('off')

    plt.show()

print("Showing predictions for 3 random images:")
for i in np.random.choice(len(X), 3, replace=False):
    show_pred(i)
# Out:
# Showing predictions for 3 random images:

# %%
# 8. Save the model
model.save('deepglobe_unet_miou_improved_ioufix3.keras')

# For Colab: download saved model (optional)
try:
    from google.colab import files
    files.download('deepglobe_unet_miou_improved_ioufix3.keras')
except:
    print("File download skipped (not running in Colab).")
